# %%
import tkinter as tk
import tkinter.messagebox
from tkinter.constants import SUNKEN


Calculator = tk.Tk()
Calculator.title('Calculator')

main_frame = tk.Frame(master=Calculator, bg="black", padx=10)
main_frame.pack()

main = tk.Entry(master=main_frame, relief=SUNKEN, borderwidth=3, width=30)
main.grid(row=0, column=0, columnspan=3, ipady=2, pady=2)



def myclick(num):
	main.insert(tk.END, num)


def equal():
	try:
		y = str(eval(main.get()))
		main.delete(0, tk.END)
		main.insert(0, y)
	except:
		tkinter.messagebox.showinfo("Error", "Syntax Error")


def clear():
	main.delete(0, tk.END)


one_btn = tk.Button(master=main_frame, text='1', padx=15, pady=5, width=3, command=lambda: myclick(1))
one_btn.grid(row=1, column=0, pady=2)

two_btn = tk.Button(master=main_frame, text='2', padx=15, pady=5, width=3, command=lambda: myclick(2))
two_btn.grid(row=1, column=1, pady=2)

three_btn = tk.Button(master=main_frame, text='3', padx=15, pady=5, width=3, command=lambda: myclick(3))
three_btn.grid(row=1, column=2, pady=2)

four_btn = tk.Button(master=main_frame, text='4', padx=15, pady=5, width=3, command=lambda: myclick(4))
four_btn.grid(row=2, column=0, pady=2)

five_btn = tk.Button(master=main_frame, text='5', padx=15, pady=5, width=3, command=lambda: myclick(5))
five_btn.grid(row=2, column=1, pady=2)

six_btn = tk.Button(master=main_frame, text='6', padx=15, pady=5, width=3, command=lambda: myclick(6))
six_btn.grid(row=2, column=2, pady=2)

seven_btn = tk.Button(master=main_frame, text='7', padx=15, pady=5, width=3, command=lambda: myclick(7))
seven_btn.grid(row=3, column=0, pady=2)

eight_btn = tk.Button(master=main_frame, text='8', padx=15, pady=5, width=3, command=lambda: myclick(8))
eight_btn.grid(row=3, column=1, pady=2)

nine_btn = tk.Button(master=main_frame, text='9', padx=15, pady=5, width=3, command=lambda: myclick(9))
nine_btn.grid(row=3, column=2, pady=2)

double_zero_btn = tk.Button(master=main_frame, text='00', padx=15, pady=5, width=3, command=lambda: myclick('00'))
double_zero_btn.grid(row=4, column=0, pady=2)

zero_btn = tk.Button(master=main_frame, text='0', padx=15, pady=5, width=3, command=lambda: myclick(0))
zero_btn.grid(row=4, column=1, pady=2)

point_btn = tk.Button(master=main_frame, text='.', padx=15, pady=5, width=3, command=lambda: myclick('.'))
point_btn.grid(row=4, column=2, pady=2)

add_btn = tk.Button(master=main_frame, text="+", padx=15, pady=5, width=3, command=lambda: myclick('+'))
add_btn.grid(row=5, column=0, pady=2)

subtract_btn = tk.Button(master=main_frame, text="-", padx=15, pady=5, width=3, command=lambda: myclick('-'))
subtract_btn.grid(row=5, column=1, pady=2)

multiply_btn = tk.Button(master=main_frame, text="*", padx=15, pady=5, width=3, command=lambda: myclick('*'))
multiply_btn.grid(row=5, column=2, pady=2)

division_btn = tk.Button(master=main_frame, text="/", padx=15, pady=5, width=3, command=lambda: myclick('/'))
division_btn.grid(row=6, column=0, pady=2)

clear_btn = tk.Button(master=main_frame, text="clear", padx=15, pady=5, width=3, command=clear)
clear_btn.grid(row=6, column=1, pady=2)

equal_btn = tk.Button(master=main_frame, text="=", padx=15, pady=5, width=3, command=equal)
equal_btn.grid(row=6, column=2, pady=2)

Calculator.mainloop()
